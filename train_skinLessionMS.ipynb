# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tfa-nightly
# !pip install import-ipynb
import import_ipynb
import tensorflow as tf
import numpy as np
import os
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
from tqdm import tqdm
from fastprogress import master_bar, progress_bar
# %cd '/content/drive/MyDrive/LMSLoss'
# Out:
# Collecting tfa-nightly
#   Downloading https://files.pythonhosted.org/packages/c1/b1/ec24cfa2c93df1e52fa235ce6d154cce1013f27ce69f7a6be1b3ed8a54fe/tfa_nightly-0.12.0.dev20201208041358-cp36-cp36m-manylinux2010_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 5.8MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tfa-nightly) (2.7.1)
# Installing collected packages: tfa-nightly
# Successfully installed tfa-nightly-0.12.0.dev20201208041358
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp36-none-any.whl size=2976 sha256=f52137148ac0d769738410a451ad78860eee2edde403ec14701befb5cd8302e8
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# /content/drive/MyDrive/LMSLoss

# %%
# %run UnetModel.ipynb
# %run MumfordLoss.ipynb
# %run augment_data.ipynb
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 576         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# swish (Swish)                   (None, 128, 128, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36864       swish[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# swish_1 (Swish)                 (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1, 1, 64)     0           swish_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 16)     1040        lambda[0][0]
# __________________________________________________________________________________________________
# swish_2 (Swish)                 (None, 1, 1, 16)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 64)     1088        swish_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1, 1, 64)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# output_block_1 (Multiply)       (None, 128, 128, 64) 0           activation[0][0]
#                                                                  swish_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           output_block_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  73728       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# swish_3 (Swish)                 (None, 64, 64, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  147456      swish_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# swish_4 (Swish)                 (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 1, 128)    0           swish_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 32)     4128        lambda_1[0][0]
# __________________________________________________________________________________________________
# swish_5 (Swish)                 (None, 1, 1, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 128)    4224        swish_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# output_block_2 (Multiply)       (None, 64, 64, 128)  0           activation_1[0][0]
#                                                                  swish_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           output_block_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  294912      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# swish_6 (Swish)                 (None, 32, 32, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  589824      swish_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# swish_7 (Swish)                 (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 256)    0           swish_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1, 64)     16448       lambda_2[0][0]
# __________________________________________________________________________________________________
# swish_8 (Swish)                 (None, 1, 1, 64)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 256)    16640       swish_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 1, 256)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# output_block_3 (Multiply)       (None, 32, 32, 256)  0           activation_2[0][0]
#                                                                  swish_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           output_block_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  1179648     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# swish_9 (Swish)                 (None, 16, 16, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  2359296     swish_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# swish_10 (Swish)                (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 1, 512)    0           swish_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 128)    65664       lambda_3[0][0]
# __________________________________________________________________________________________________
# swish_11 (Swish)                (None, 1, 1, 128)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 512)    66048       swish_11[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 1, 512)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# output_block_4 (Multiply)       (None, 16, 16, 512)  0           activation_3[0][0]
#                                                                  swish_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)    0           output_block_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 512)    2359296     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# swish_12 (Swish)                (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 512)    2359296     swish_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# swish_13 (Swish)                (None, 8, 8, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 1, 512)    0           swish_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 128)    65664       lambda_4[0][0]
# __________________________________________________________________________________________________
# swish_14 (Swish)                (None, 1, 1, 128)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 1, 512)    66048       swish_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 512)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# output_block_5 (Multiply)       (None, 8, 8, 512)    0           activation_4[0][0]
#                                                                  swish_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 512)    0           output_block_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 128)    65536       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1, 1, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    65536       output_block_5[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    589824      output_block_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    1638400     output_block_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 128)    3211264     output_block_5[0][0]
# __________________________________________________________________________________________________
# swish_15 (Swish)                (None, 1, 1, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 128)    512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 128)    0           swish_15[0][0]
# __________________________________________________________________________________________________
# swish_17 (Swish)                (None, 8, 8, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# swish_19 (Swish)                (None, 8, 8, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# swish_21 (Swish)                (None, 8, 8, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# swish_23 (Swish)                (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 128)    0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 1, 128)    0           swish_17[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 1, 128)    0           swish_19[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1, 1, 128)    0           swish_21[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1, 1, 128)    0           swish_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 1, 32)     4128        lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 1, 1, 32)     4128        lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 1, 1, 32)     4128        lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 1, 1, 32)     4128        lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1, 1, 32)     4128        lambda_9[0][0]
# __________________________________________________________________________________________________
# swish_16 (Swish)                (None, 1, 1, 32)     0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# swish_18 (Swish)                (None, 1, 1, 32)     0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# swish_20 (Swish)                (None, 1, 1, 32)     0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# swish_22 (Swish)                (None, 1, 1, 32)     0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# swish_24 (Swish)                (None, 1, 1, 32)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 1, 128)    4224        swish_16[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 128)    4224        swish_18[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 1, 1, 128)    4224        swish_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 128)    4224        swish_22[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1, 1, 128)    4224        swish_24[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 1, 128)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 128)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 1, 128)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 1, 128)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 1, 128)    0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 8, 8, 128)    0           activation_5[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 8, 8, 128)    0           activation_6[0][0]
#                                                                  swish_17[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 8, 8, 128)    0           activation_7[0][0]
#                                                                  swish_19[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 8, 8, 128)    0           activation_8[0][0]
#                                                                  swish_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 8, 8, 128)    0           activation_9[0][0]
#                                                                  swish_23[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 512)  2359296     output_block_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 640)    0           multiply[0][0]
#                                                                  multiply_1[0][0]
#                                                                  multiply_2[0][0]
#                                                                  multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 512)  2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 128)    81920       concatenate[0][0]
# __________________________________________________________________________________________________
# swish_27 (Swish)                (None, 16, 16, 512)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 512)  2359296     swish_27[0][0]
# __________________________________________________________________________________________________
# swish_25 (Swish)                (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 512)  2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1, 1, 128)    0           swish_25[0][0]
# __________________________________________________________________________________________________
# swish_28 (Swish)                (None, 16, 16, 512)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 1, 1, 32)     4128        lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1, 1, 512)    0           swish_28[0][0]
# __________________________________________________________________________________________________
# swish_26 (Swish)                (None, 1, 1, 32)     0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 1, 1, 128)    65664       lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 1, 1, 128)    4224        swish_26[0][0]
# __________________________________________________________________________________________________
# swish_29 (Swish)                (None, 1, 1, 128)    0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 128)    0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 1, 1, 512)    66048       swish_29[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 8, 8, 128)    0           activation_10[0][0]
#                                                                  swish_25[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 512)    0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  262656      multiply_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 16, 16, 512)  0           activation_11[0][0]
#                                                                  swish_28[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1024) 0           conv2d_transpose[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 512)  4718592     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 512)  2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 256)  589824      output_block_3[0][0]
# __________________________________________________________________________________________________
# swish_30 (Swish)                (None, 16, 16, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 256)  1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 512)  2359296     swish_30[0][0]
# __________________________________________________________________________________________________
# swish_33 (Swish)                (None, 32, 32, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 512)  2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 256)  589824      swish_33[0][0]
# __________________________________________________________________________________________________
# swish_31 (Swish)                (None, 16, 16, 512)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1, 1, 512)    0           swish_31[0][0]
# __________________________________________________________________________________________________
# swish_34 (Swish)                (None, 32, 32, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 1, 1, 128)    65664       lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1, 1, 256)    0           swish_34[0][0]
# __________________________________________________________________________________________________
# swish_32 (Swish)                (None, 1, 1, 128)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 1, 1, 64)     16448       lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 1, 1, 512)    66048       swish_32[0][0]
# __________________________________________________________________________________________________
# swish_35 (Swish)                (None, 1, 1, 64)     0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 512)    0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 1, 1, 256)    16640       swish_35[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 16, 16, 512)  0           activation_12[0][0]
#                                                                  swish_31[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 1, 256)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  524544      multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 32, 32, 256)  0           activation_13[0][0]
#                                                                  swish_34[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_1[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 256)  1179648     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 256)  1024        conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 128)  147456      output_block_2[0][0]
# __________________________________________________________________________________________________
# swish_36 (Swish)                (None, 32, 32, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 128)  512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 256)  589824      swish_36[0][0]
# __________________________________________________________________________________________________
# swish_39 (Swish)                (None, 64, 64, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 256)  1024        conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 128)  147456      swish_39[0][0]
# __________________________________________________________________________________________________
# swish_37 (Swish)                (None, 32, 32, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1, 1, 256)    0           swish_37[0][0]
# __________________________________________________________________________________________________
# swish_40 (Swish)                (None, 64, 64, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 1, 1, 64)     16448       lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1, 1, 128)    0           swish_40[0][0]
# __________________________________________________________________________________________________
# swish_38 (Swish)                (None, 1, 1, 64)     0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 1, 1, 32)     4128        lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 1, 1, 256)    16640       swish_38[0][0]
# __________________________________________________________________________________________________
# swish_41 (Swish)                (None, 1, 1, 32)     0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 1, 256)    0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 1, 1, 128)    4224        swish_41[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 32, 32, 256)  0           activation_14[0][0]
#                                                                  swish_37[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 1, 128)    0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 128)  131200      multiply_9[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 64, 64, 128)  0           activation_15[0][0]
#                                                                  swish_40[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_2[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 128)  294912      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 128)  512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 128, 128, 64) 36864       output_block_1[0][0]
# __________________________________________________________________________________________________
# swish_42 (Swish)                (None, 64, 64, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 128)  147456      swish_42[0][0]
# __________________________________________________________________________________________________
# swish_45 (Swish)                (None, 128, 128, 64) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 128)  512         conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 128, 128, 64) 36864       swish_45[0][0]
# __________________________________________________________________________________________________
# swish_43 (Swish)                (None, 64, 64, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 64) 256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1, 1, 128)    0           swish_43[0][0]
# __________________________________________________________________________________________________
# swish_46 (Swish)                (None, 128, 128, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 1, 1, 32)     4128        lambda_16[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 1, 1, 64)     0           swish_46[0][0]
# __________________________________________________________________________________________________
# swish_44 (Swish)                (None, 1, 1, 32)     0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 1, 1, 16)     1040        lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 1, 1, 128)    4224        swish_44[0][0]
# __________________________________________________________________________________________________
# swish_47 (Swish)                (None, 1, 1, 16)     0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 1, 128)    0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 1, 1, 64)     1088        swish_47[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 64, 64, 128)  0           activation_16[0][0]
#                                                                  swish_43[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 1, 64)     0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 32832       multiply_11[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 128, 128, 64) 0           activation_17[0][0]
#                                                                  swish_46[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_3[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# swish_48 (Swish)                (None, 128, 128, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 64) 36864       swish_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 128, 64) 256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# swish_49 (Swish)                (None, 128, 128, 64) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 1, 1, 64)     0           swish_49[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 1, 1, 16)     1040        lambda_18[0][0]
# __________________________________________________________________________________________________
# swish_50 (Swish)                (None, 1, 1, 16)     0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 1, 1, 64)     1088        swish_50[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 1, 64)     0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 128, 128, 64) 0           activation_18[0][0]
#                                                                  swish_49[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 128, 128, 1)  577         multiply_13[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 128, 128, 1)  0           conv2d_70[0][0]
# ==================================================================================================
# Total params: 32,410,257
# Trainable params: 32,395,153
# Non-trainable params: 15,104
# __________________________________________________________________________________________________

# %%
import keras.backend as K

def dice_coef(y_true, y_pred, smooth=1e-10):
    '''Average dice coefficient per batch.'''
    axes = (1,2,3)
    intersection = K.sum(y_true * y_pred, axis=axes)
    summation = K.sum(y_true + y_pred, axis=axes)
    return K.mean((2.0 * intersection + smooth) / (summation + smooth), axis=0)

def jaccard_coef(y_true, y_pred, smooth=1e-10):
    '''Average jaccard coefficient per batch.'''
    axes = (1,2,3)
    intersection = K.sum(y_true * y_pred, axis=axes)
    union = K.sum(y_true + y_pred, axis=axes) - intersection
    return K.mean( (intersection + smooth) / (union + smooth), axis=0)

# %%
x =  np.load("dataISIC2018/x.npy")
y = np.load("dataISIC2018/y.npy")
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state =42)
x_train=tf.convert_to_tensor(x_train,tf.float32)
y_train=tf.convert_to_tensor(y_train,tf.float32)
x_test=tf.convert_to_tensor(x_test,tf.float32)
y_test=tf.convert_to_tensor(y_test,tf.float32)

# %%
BATCH_SIZE = 32
buffer_size = x_train.shape[0]

@tf.function
def gen_image(image,mask):
  # image, mask = brightness(image,mask)
  #image, mask = saturation(image,mask)
  image, mask = flip(image,mask)
  image, mask = rotate_image(image,mask)
  image, mask = normalize(image, mask)
  return image, mask
train_dataset = tf.data.Dataset.from_tensor_slices((x_train,y_train)).shuffle(buffer_size).map(gen_image).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test,y_test)).map(normalize).batch(BATCH_SIZE*2)
# val_dataset = tf.data.Dataset.from_tensor_slices((x_val,y_val)).map(normalize).batch(BATCH_SIZE*2)

# %% [markdown]
# ## Image-Driven Active Contour Loss

# %%
class MSLoss_vs2():
  def levelsetLoss(self,target, output):
    loss = 0.0
    for ich in range(target.shape[3]):
        target_ = target[...,ich:ich+1]    
        pcentroid = tf.reduce_sum(target_ * output, (1,2),keepdims=True)/tf.reduce_sum(output, (1,2),keepdims = True)   
        plevel = target_ - pcentroid
        pLoss = plevel * plevel * output
        loss += tf.reduce_sum(pLoss)
    return loss
      
  def activeContourLoss(self,y_true,y_pred,outDim =2,smooth=0.001):     
    yTrueOnehot = tf.one_hot(tf.squeeze(tf.cast(y_true,tf.uint8),axis=-1), depth = outDim)
    loss =  y_pred * (1-yTrueOnehot) + (1-y_pred)*yTrueOnehot
    return tf.reduce_mean(loss)
    #this is Luac:
    # loss =  - tf.cast(tf.math.log(1-y_pred+smooth),tf.float32) * (1-yTrueOnehot ) - tf.cast(tf.math.log(y_pred+smooth),tf.float32)*yTrueOnehot
    # return tf.reduce_mean(loss)
                    
  def gradientLoss(self,input,penalty = "l1"):

    dH = tf.math.abs(input[:, 1:, :, :] - input[:, :-1, :, :])
    dW = tf.math.abs(input[:, :, 1:, :] - input[:, :, :-1, :])
    if penalty == "l2":
        dH = dH * dH
        dW = dW * dW

    loss =  tf.reduce_sum(dH) +  tf.reduce_sum(dW)
    return loss

# %% [markdown]
# ## Training

# %%
class Mumford_Unet_vs2(MSLoss_vs2):
  def __init__(self,model):
    super().__init__()
    self.model = model
    self.optimizer = None
    self.trainData = None
    self.testData = None
    self.batch_size = BATCH_SIZE
    temp = x_train.shape[0] // self.batch_size
    self.train_step = temp + 1 if x_train.shape[0] % self.batch_size != 0 else temp
    self.learning_rate = 0.001

  def optimizer_fc(self,op_type = "adam", op_param = 0.005):
    if op_type == 'adam':
      self.optimizer =  tf.keras.optimizers.Adam(op_param)
    elif op_type == "nadam":
      self.optimizer =  tf.keras.optimizers.Nadam(op_param)

  def loss(self, image, output, trueLabel, alpha = 1e-3, beta = 0.001):
    print('\ractive loss: ',self.activeContourLoss(trueLabel, output),' leverset loss: ', self.levelsetLoss(image,output),'gradient loss: ', self.gradientLoss(output), end="")
    return alpha * ( self.levelsetLoss(image,output) + beta * self.gradientLoss(output)) + self.activeContourLoss(trueLabel, output)
    # return self.activeContourLoss(trueLabel, output)

  def metrics(self,y_true,y_pred):
    output_standard = tf.expand_dims(tf.argmax(y_pred,axis=-1),axis = -1)
    output_standard = tf.cast(output_standard,tf.float32)
    dice = dice_coef(y_true, output_standard)
    jaccard = jaccard_coef(y_true, output_standard)
    return dice, jaccard

  def evaluateTest(self,testDataset):
    test_dices =  []
    test_jaccards =  []
    for xBatchTest, yBatchTest in testDataset:
      yPredBatchTest = self.model(xBatchTest, training =False)
      diceTest, jaccardTest =  self.metrics(yBatchTest, yPredBatchTest)
      test_dices.append(diceTest)
      test_jaccards.append(jaccardTest)
    return np.mean(test_dices), np.mean(test_jaccards)

  def epoch_training(self,model,optimizer, trainDataset, testDataset, mb, stepTrain, alpha_loss, beta_loss):
    train_losses = []
    train_dices =  []
    train_jaccards =  []

    trainDataset = iter(trainDataset)  
    for _ in progress_bar(range(stepTrain),parent = mb):   
      with tf.GradientTape() as tape:
        image, y_true = next(trainDataset)
        y_pred = self.model(image, training = True)
        total_loss  =  self.loss(image, y_pred, y_true, alpha_loss, beta_loss)

      
      grad  = tape.gradient(total_loss, self.model.trainable_variables)
      optimizer.apply_gradients(zip(grad,self.model.trainable_variables))

      diceTrain, jaccardTrain =  self.metrics(y_true, y_pred)

      mb.child.comment = 'Train loss {:.4f}'.format(total_loss)

      train_losses.append(total_loss)
      train_dices.append(diceTrain)
      train_jaccards.append(jaccardTrain)

    trainLossMean = np.mean(train_losses)
    trainDiceMean = np.mean(train_dices)
    trainJaccardMean = np.mean(train_jaccards)

    testDiceMean, testJaccardMean = self.evaluateTest(testDataset)

    return trainLossMean, trainDiceMean, trainJaccardMean, testDiceMean, testJaccardMean


  def train(self,num_epoch, reduceLrEpoch=10 , earlyStoping=22, minLr=1e-5, alpha_loss= 1e-6, beta_loss = 1,checkpoint_prefix = "m"):
    mb = master_bar(range(num_epoch))
    epochs_list = []
    history = dict()
    training_losses = []
    trainDice_list = []
    trainJaccard_list = []
    testDice_list = []
    testJaccard_list = []
    # learningRate_list = []
    best_score  = 0
    count = 0
    for epoch in mb:
      count += 1
      epochs_list.append(epoch+1)

      trainLoss, trainDice, trainJaccard, testDice, testJaccard  \
      = self.epoch_training(self.model, self.optimizer, self.trainData, self.testData, mb, self.train_step, alpha_loss, beta_loss)

      mb.write('Finish train epoch {} with loss {:.4f} trainDice: {:.2f}, trainJaccard: {:.2f}, testDice: {:.2f},\
       testJaccard: {:.2f}'.format(epoch+1, trainLoss, trainDice, trainJaccard, testDice, testJaccard))

      training_losses.append(trainLoss)
      trainDice_list.append(trainDice)
      trainJaccard_list.append(trainJaccard)
      testDice_list.append(testDice)
      testJaccard_list.append(testJaccard)
      # learningRate_list.append(self.learning_rate)

      if count % reduceLrEpoch ==0 :
        self.learning_rate = self.learning_rate * 0.5
        if self.learning_rate < minLr:
          self.learning_rate = minLr
        print('learning rate is set to : ',self.learning_rate)
        self.optimizer.learning_rate.assign(self.learning_rate )
    
      mb.update_graph([[epochs_list, training_losses]], [0,num_epoch], [0,0.1])
      if count == earlyStoping :
        break
      ### Check point here ###
      ### Check point follow testDice ###
      if best_score < testDice:
          count = 0
          mb.write(">>> Improved Dice-score EPI from {:.4f} to {:.4f}".format(best_score, testDice))
          best_score = testDice
          self.model.save_weights(checkpoint_prefix.format(score=best_score))
    history['epoch'] = epochs_list
    history['train_loss'] = training_losses
    history['train_dice'] = trainDice_list
    history['train_jaccard'] = trainJaccard_list
    history['test_dice'] = testDice_list
    history['test_jaccard'] = testJaccard_list
    # history['lr'] = learningRate_list
    return history

# %%
S = seg_net((128,160,3),out_channels=2)
nhat = Mumford_Unet_vs2(S)
nhat.learning_rate = 0.001
nhat.trainData = train_dataset
nhat.testData = test_dataset
nhat.optimizer_fc(op_type = "nadam", op_param=nhat.learning_rate)

# %%
history = nhat.train(300,alpha_loss=1e-6,beta_loss=1e-2,checkpoint_prefix="./weightISIC_MS/ckpt_{score:.4f}.h5")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='62' class='' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.67% [62/300 1:05:09<4:10:08]
#     </div>
#
# Finish train epoch 1 with loss 0.1594 trainDice: 0.70, trainJaccard: 0.60, testDice: 0.43,       testJaccard: 0.32<p>>>> Improved Dice-score EPI from 0.0000 to 0.4339<p>Finish train epoch 2 with loss 0.1096 trainDice: 0.76, trainJaccard: 0.67, testDice: 0.42,       testJaccard: 0.32<p>Finish train epoch 3 with loss 0.0963 trainDice: 0.80, trainJaccard: 0.71, testDice: 0.64,       testJaccard: 0.53<p>>>> Improved Dice-score EPI from 0.4339 to 0.6412<p>Finish train epoch 4 with loss 0.0905 trainDice: 0.81, trainJaccard: 0.73, testDice: 0.75,       testJaccard: 0.64<p>>>> Improved Dice-score EPI from 0.6412 to 0.7474<p>Finish train epoch 5 with loss 0.0915 trainDice: 0.81, trainJaccard: 0.73, testDice: 0.70,       testJaccard: 0.59<p>Finish train epoch 6 with loss 0.0879 trainDice: 0.82, trainJaccard: 0.74, testDice: 0.77,       testJaccard: 0.67<p>>>> Improved Dice-score EPI from 0.7474 to 0.7713<p>Finish train epoch 7 with loss 0.0855 trainDice: 0.83, trainJaccard: 0.74, testDice: 0.80,       testJaccard: 0.71<p>>>> Improved Dice-score EPI from 0.7713 to 0.7996<p>Finish train epoch 8 with loss 0.0848 trainDice: 0.83, trainJaccard: 0.75, testDice: 0.79,       testJaccard: 0.70<p>Finish train epoch 9 with loss 0.0832 trainDice: 0.84, trainJaccard: 0.76, testDice: 0.78,       testJaccard: 0.68<p>Finish train epoch 10 with loss 0.0843 trainDice: 0.83, trainJaccard: 0.75, testDice: 0.83,       testJaccard: 0.74<p>>>> Improved Dice-score EPI from 0.7996 to 0.8276<p>Finish train epoch 11 with loss 0.0826 trainDice: 0.84, trainJaccard: 0.76, testDice: 0.77,       testJaccard: 0.67<p>Finish train epoch 12 with loss 0.0856 trainDice: 0.83, trainJaccard: 0.75, testDice: 0.76,       testJaccard: 0.67<p>Finish train epoch 13 with loss 0.0810 trainDice: 0.84, trainJaccard: 0.76, testDice: 0.83,       testJaccard: 0.75<p>>>> Improved Dice-score EPI from 0.8276 to 0.8337<p>Finish train epoch 14 with loss 0.0785 trainDice: 0.85, trainJaccard: 0.77, testDice: 0.83,       testJaccard: 0.75<p>>>> Improved Dice-score EPI from 0.8337 to 0.8340<p>Finish train epoch 15 with loss 0.0776 trainDice: 0.85, trainJaccard: 0.77, testDice: 0.83,       testJaccard: 0.74<p>Finish train epoch 16 with loss 0.0803 trainDice: 0.84, trainJaccard: 0.76, testDice: 0.84,       testJaccard: 0.76<p>>>> Improved Dice-score EPI from 0.8340 to 0.8381<p>Finish train epoch 17 with loss 0.0785 trainDice: 0.85, trainJaccard: 0.77, testDice: 0.85,       testJaccard: 0.77<p>>>> Improved Dice-score EPI from 0.8381 to 0.8507<p>Finish train epoch 18 with loss 0.0757 trainDice: 0.85, trainJaccard: 0.78, testDice: 0.83,       testJaccard: 0.75<p>Finish train epoch 19 with loss 0.0781 trainDice: 0.85, trainJaccard: 0.77, testDice: 0.84,       testJaccard: 0.76<p>Finish train epoch 20 with loss 0.0770 trainDice: 0.86, trainJaccard: 0.78, testDice: 0.74,       testJaccard: 0.62<p>Finish train epoch 21 with loss 0.0812 trainDice: 0.84, trainJaccard: 0.76, testDice: 0.81,       testJaccard: 0.71<p>Finish train epoch 22 with loss 0.0772 trainDice: 0.85, trainJaccard: 0.77, testDice: 0.83,       testJaccard: 0.75<p>Finish train epoch 23 with loss 0.0737 trainDice: 0.86, trainJaccard: 0.78, testDice: 0.84,       testJaccard: 0.75<p>Finish train epoch 24 with loss 0.0731 trainDice: 0.86, trainJaccard: 0.79, testDice: 0.84,       testJaccard: 0.76<p>Finish train epoch 25 with loss 0.0726 trainDice: 0.86, trainJaccard: 0.79, testDice: 0.85,       testJaccard: 0.77<p>>>> Improved Dice-score EPI from 0.8507 to 0.8510<p>Finish train epoch 26 with loss 0.0714 trainDice: 0.87, trainJaccard: 0.79, testDice: 0.86,       testJaccard: 0.78<p>>>> Improved Dice-score EPI from 0.8510 to 0.8616<p>Finish train epoch 27 with loss 0.0707 trainDice: 0.87, trainJaccard: 0.79, testDice: 0.85,       testJaccard: 0.78<p>Finish train epoch 28 with loss 0.0709 trainDice: 0.87, trainJaccard: 0.79, testDice: 0.85,       testJaccard: 0.77<p>Finish train epoch 29 with loss 0.0725 trainDice: 0.87, trainJaccard: 0.79, testD ...
# active loss:  tf.Tensor(0.08766642, shape=(), dtype=float32)  leverset loss:  tf.Tensor(16696.102, shape=(), dtype=float32) gradient loss:  tf.Tensor(15122.621, shape=(), dtype=float32)
# active loss:  tf.Tensor(0.048644986, shape=(), dtype=float32)  leverset loss:  tf.Tensor(21928.793, shape=(), dtype=float32) gradient loss:  tf.Tensor(15955.007, shape=(), dtype=float32)learning rate is set to :  0.0005
# active loss:  tf.Tensor(0.027828405, shape=(), dtype=float32)  leverset loss:  tf.Tensor(19630.857, shape=(), dtype=float32) gradient loss:  tf.Tensor(16353.856, shape=(), dtype=float32)learning rate is set to :  0.00025
# active loss:  tf.Tensor(0.050791018, shape=(), dtype=float32)  leverset loss:  tf.Tensor(16000.628, shape=(), dtype=float32) gradient loss:  tf.Tensor(15003.082, shape=(), dtype=float32)

# %%
sio.savemat('./weightISIC_MS/historyISIC_MS.mat',history)

# %%
nhat.model.load_weights('/content/drive/MyDrive/LMSLoss/weightISIC_MS/ckpt_0.8829.h5')

# %%
nhat.evaluateTest(test_dataset)
# Out:
# (0.88288844, 0.8087215)

# %%
for i in range(x_test.shape[0]):
  y_pred = nhat.model(normalize(x_test[i:i+1],y_test[i:i+1]))
  y_predShow = np.argmax(y_pred,axis = -1)
  plt.figure(i+1)
  plt.subplot(131),plt.imshow(x_test[i]),plt.title('image')
  plt.subplot(132),plt.imshow(y_predShow[0],cmap ='gray'),plt.title('predict')
  plt.subplot(133),plt.imshow(y_test[i,...,0],cmap='gray'),plt.title('groundtruth')
